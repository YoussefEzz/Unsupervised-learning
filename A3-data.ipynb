# %%
import pandas as pd
import numpy as np

#read and parse the training set .csv features file 
df = pd.read_csv('Datasets/A3-data.txt', delimiter = ',')
df.head()
# Out:
#           x         y         z         t  class
# 0 -0.031676 -9.912054 -0.579436 -1.044239      1
# 1  0.002526  6.172456  3.288339 -1.006427      5
# 2  0.183123 -0.387841  6.236470 -1.691491      2
# 3 -0.042262 -1.996272 -1.655302 -2.995311      1
# 4 -0.062811 -0.417072  6.657475 -3.633134      4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       360 non-null    float64
#  1   y       360 non-null    float64
#  2   z       360 non-null    float64
#  3   t       360 non-null    float64
#  4   class   360 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 14.2 KB

# %%
df.describe()
# Out:
#                 x           y           z           t       class
# count  360.000000  360.000000  360.000000  360.000000  360.000000
# mean     0.030880    0.685121    3.973543   -0.318865    3.516667
# std      0.377520    4.900030    4.050409    3.321348    1.931919
# min     -0.819698   -9.912054   -4.573732   -7.954909    1.000000
# 25%     -0.140746   -2.033918    0.610788   -2.694196    2.000000
# 50%      0.002011    0.214840    4.988976   -0.246234    3.000000
# 75%      0.242461    4.182701    7.123379    1.665129    6.000000
# max      0.922136   10.812646   11.604825    7.976116    6.000000

# %%
df.dtypes
# Out:
# x        float64
# y        float64
# z        float64
# t        float64
# class      int64
# dtype: object

# %%
#investigate the data
import matplotlib.pyplot as plt


#read four input(features) columns
x = df[df.columns[0]]
y = df[df.columns[1]]
z = df[df.columns[2]]
t = df[df.columns[3]]

#read one output(class) column
class_ = df[df.columns[4]]

data = [x, y, z, t]
print((data))
labels = ['x', 'y', 'z', 't']
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(data,
                notch=True,  # notch shape
                vert=True,  # vertical box alignment
                patch_artist=True,  # fill with color
                labels=labels)
 
# show plot
plt.show()
# Out:
# [0     -0.031676
# 1      0.002526
# 2      0.183123
# 3     -0.042262
# 4     -0.062811
#          ...
# 355   -0.340733
# 356   -0.024928
# 357   -0.668529
# 358   -0.122711
# 359    0.740207
# Name: x, Length: 360, dtype: float64, 0     -9.912054
# 1      6.172456
# 2     -0.387841
# 3     -1.996272
# 4     -0.417072
#          ...
# 355    8.504536
# 356    1.551977
# 357   -0.607597
# 358   -5.516957
# 359   -7.492176
# Name: y, Length: 360, dtype: float64, 0     -0.579436
# 1      3.288339
# 2      6.236470
# 3     -1.655302
# 4      6.657475
#          ...
# 355    7.903644
# 356    6.361992
# 357    0.639295
# 358   -2.111173
# 359    1.959426
# Name: z, Length: 360, dtype: float64, 0     -1.044239
# 1     -1.006427
# 2     -1.691491
# 3     -2.995311
# 4     -3.633134
#          ...
# 355   -2.032197
# 356   -0.757714
# 357    4.329213
# 358    2.209675
# 359   -7.119918
# Name: t, Length: 360, dtype: float64]
